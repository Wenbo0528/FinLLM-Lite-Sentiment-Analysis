# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install bitsandbytes accelerate peft

# %%
# %cd /content/drive/MyDrive/Columbia_Semester3/5293/Final/FinLLM-Sentiment-Analysis/FinLLM-Instruction-tuning/train

# %%
# %cd /content/drive/MyDrive/Columbia_Semester3/5293/Final/FinLLM-Sentiment-Analysis/FinLLM-Instruction-tuning/data/data_preparation
# !python

# %%
# %cd /content/drive/MyDrive/Columbia_Semester3/5293/Final/FinLLM-Sentiment-Analysis/FinLLM-Instruction-tuning/train
# !python train.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Columbia_Semester3/5293/Final/FinLLM-Sentiment-Analysis/FinLLM-Instruction-tuning/train/train.py", line 3, in <module>
#     import torch
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 405, in <module>
#     from torch._C import *  # noqa: F403
#     ^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 216, in _lock_unlock_module
# KeyboardInterrupt
# ^C
